# %%
import scipy as sy
import pandas as pd
df=pd.read_csv(r"C:\Users\hanal\Downloads\dataset.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
print("MEAN:")
grp=df.groupby('target')
grp.mean()
# Out:
# MEAN:
#               age       sex        cp    trestbps        chol       fbs  \
# target
# 0       56.601449  0.826087  0.478261  134.398551  251.086957  0.159420
# 1       52.496970  0.563636  1.375758  129.303030  242.230303  0.139394
#
#          restecg     thalach     exang   oldpeak     slope        ca      thal
# target
# 0       0.449275  139.101449  0.550725  1.585507  1.166667  1.166667  2.543478
# 1       0.593939  158.466667  0.139394  0.583030  1.593939  0.363636  2.121212

# %%
print("MEDIAN:")
grp=df.groupby('target')
grp.median()
# Out:
# MEDIAN:
#          age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  \
# target
# 0       58.0  1.0  0.0     130.0  249.0  0.0      0.0    142.0    1.0
# 1       52.0  1.0  2.0     130.0  234.0  0.0      1.0    161.0    0.0
#
#         oldpeak  slope   ca  thal
# target
# 0           1.4    1.0  1.0   3.0
# 1           0.2    2.0  0.0   2.0

# %%
print("STANDARD DEVIATION:")
grp=df.groupby('target')
grp.std()
# Out:
# STANDARD DEVIATION:
#              age       sex        cp   trestbps       chol       fbs  \
# target
# 0       7.962082  0.380416  0.905920  18.729944  49.454614  0.367401
# 1       9.550651  0.497444  0.952222  16.169613  53.552872  0.347412
#
#          restecg    thalach     exang   oldpeak     slope        ca      thal
# target
# 0       0.541321  22.598782  0.499232  1.300340  0.561324  1.043460  0.684762
# 1       0.504818  19.174276  0.347412  0.780683  0.593635  0.848894  0.465752

# %%
print("SKEWNESS:")
grp=df.groupby('target')
grp.skew()
# Out:
# SKEWNESS:
#              age       sex        cp  trestbps      chol       fbs   restecg  \
# target
# 0      -0.548502 -1.739584  1.649560  0.858872  0.316402  1.881258  0.624617
# 1       0.120951 -0.258993 -0.131417  0.424543  1.745595  2.101431 -0.241816
#
#          thalach     exang   oldpeak     slope        ca      thal
# target
# 0      -0.296783 -0.206199  0.741389  0.032571  0.480970 -1.335387
# 1      -0.707711  2.101431  1.646658 -1.166896  2.796355  0.047011

# %%
print("VARIANCE:")
grp=df.groupby('target')
grp.var()
# Out:
# VARIANCE:
#               age       sex        cp    trestbps         chol       fbs  \
# target
# 0       63.394742  0.144716  0.820692  350.810801  2445.758807  0.134984
# 1       91.214930  0.247450  0.906726  261.456393  2867.910052  0.120695
#
#          restecg     thalach     exang   oldpeak     slope        ca      thal
# target
# 0       0.293029  510.704961  0.249233  1.690883  0.315085  1.088808  0.468899
# 1       0.254841  367.652846  0.120695  0.609466  0.352402  0.720621  0.216925

# %%
print("KURTOSIS:")
grp=df.groupby('target')
grp.kurtosis()
# Out:
# KURTOSIS:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 3
#       1 print("KURTOSIS:")
#       2 grp=df.groupby('target')
# ----> 3 grp.kurtosis()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'kurtosis'

# %%
df1=df.loc[df['target']==0]
df2=df.loc[df['target']==1]
print("MODE:")
print("\nTarget 0:\n",sy.stats.mode(df1,axis=0))
print("Target 1 :\n",sy.stats.mode(df2,axis=0))

# %%
print("\n FREQUENCY:\n")
print("Target 0:\n",df1['thalach'].value_counts())
print("Tar̥get 1:\n",df2['thalach'].value_counts())

# %%
sns.pairplot(data=df,hue='target')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 sns.pairplot(data=df,hue='target')
#
# NameError: name 'sns' is not defined

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
plt.figure(figsize=(20,5))
df['trestbps'].value_counts().plot(kind='bar', xlabel='trestbps', ylabel='frequency')
plt.show()

# %%
 print("KURTOSIS:")
 print("\nTarget 0 :\n",df1.kurtosis())
 print("\n\Target 1 :\n",df2.kurtosis())
# Out:
# KURTOSIS:
#
# Target 0 :
#  age         0.128907
# sex         1.041030
# cp          1.300293
# trestbps    0.911122
# chol        0.375047
# fbs         1.561555
# restecg    -0.782672
# thalach    -0.195616
# exang      -1.986486
# oldpeak     0.411434
# slope      -0.057185
# ca         -0.784179
# thal        0.990066
# target      0.000000
# dtype: float64
#
# \Target 1 :
#  age        -0.615836
# sex        -1.956791
# cp         -1.037305
# trestbps    0.397460
# chol        7.640099
# fbs         2.445510
# restecg    -1.596734
# thalach     0.460746
# exang       2.445510
# oldpeak     3.188330
# slope       0.361720
# ca          7.908835
# thal        3.188269
# target      0.000000
# dtype: float64
# <>:3: SyntaxWarning: invalid escape sequence '\T'
# <>:3: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\hanal\AppData\Local\Temp\ipykernel_14212\2816563527.py:3: SyntaxWarning: invalid escape sequence '\T'
#   print("\n\Target 1 :\n",df2.kurtosis())

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(20,5))

df=pd.read_csv(r"C:\Users\hanal\Downloads\dataset.csv")
sns.barplot(data=df,y='age',x='trestbps',hue='sex')
# Out:
# <Axes: xlabel='trestbps', ylabel='age'>

# %%
sns.distplot(df['trestbps'],hist=False)
# Out:
# C:\Users\hanal\AppData\Local\Temp\ipykernel_14212\1356265450.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['trestbps'],hist=False)
# <Axes: xlabel='trestbps', ylabel='Density'>

# %%
import seaborn as sns
import pandas as pd

df=pd.read_csv(r"C:\Users\hanal\Downloads\dataset.csv")
sns.histplot(data=df,x='thalach',hue='sex')
# Out:
# <Axes: xlabel='thalach', ylabel='Count'>

# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv(r"C:\Users\hanal\Downloads\dataset.csv")
sns.distplot(df['thalach'],hist=False)
# Out:
# C:\Users\hanal\AppData\Local\Temp\ipykernel_16648\3097783722.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['thalach'],hist=False)
# <Axes: xlabel='thalach', ylabel='Density'>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\hanal\Downloads\dataset.csv")
sns.lineplot(df,y='age',x='oldpeak',hue='sex')
# Out:
# <Axes: xlabel='oldpeak', ylabel='age'>

# %%
import pandas as pd
import seaborn as sns

sns.set(style="whitegrid")
df=pd.read_csv(r"C:\Users\hanal\Downloads\dataset.csv")
sns.scatterplot(df,x='trestbps',y='thalach',hue='sex')
# Out:
# <Axes: xlabel='trestbps', ylabel='thalach'>

# %%
import pandas as pd
import numpy as np
import scipy as sy
df=pd.read_csv(r"C:\Users\hanal\Downloads\dataset.csv")
print("MEAN:")
print(round(np.mean(df,axis=0)),2)
print("\nMEDIAN:")
print(np.median(df,axis=0))
print("\nMODE:")
print(sy.stats.mode(df,axis=0))
print("\nSTANDARD DEVIATION:")
print(round(np.std(df,axis=0)),2)
# Out:
# MEAN:
# age          54.0
# sex           1.0
# cp            1.0
# trestbps    132.0
# chol        246.0
# fbs           0.0
# restecg       1.0
# thalach     150.0
# exang         0.0
# oldpeak       1.0
# slope         1.0
# ca            1.0
# thal          2.0
# target        1.0
# dtype: float64 2
#
# MEDIAN:
# [ 55.    1.    1.  130.  240.    0.    1.  153.    0.    0.8   1.    0.
#    2.    1. ]
#
# MODE:
# ModeResult(mode=array([ 58.,   1.,   0., 120., 197.,   0.,   1., 162.,   0.,   0.,   2.,
#          0.,   2.,   1.]), count=array([ 19., 207., 143.,  37.,   6., 258., 152.,  11., 204.,  99., 142.,
#        175., 166., 165.]))
#
# STANDARD DEVIATION:
# age          9.0
# sex          0.0
# cp           1.0
# trestbps    18.0
# chol        52.0
# fbs          0.0
# restecg      1.0
# thalach     23.0
# exang        0.0
# oldpeak      1.0
# slope        1.0
# ca           1.0
# thal         1.0
# target       0.0
# dtype: float64 2
